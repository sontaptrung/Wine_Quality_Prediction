# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import h2o
from h2o.automl import H2OAutoML
import seaborn as sns
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error

# %%
# h2o.init()

# %%
train_df = pd.read_csv('../input/ail302m/train.csv', sep=';')
test_df = pd.read_csv('../input/ail302m/test.csv', sep=';')

# %%
train_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               6.6               0.3         0.36             1.2      0.035
# 1               7.7               0.5         0.26             1.9      0.062
# 2               8.4               0.5         0.35             2.9      0.076
# 3               7.5               0.4         0.33             5.0      0.045
# 4               6.4               0.2         0.25            20.2      0.083
# ...             ...               ...          ...             ...        ...
# 6709            7.2               0.2         0.19             7.7      0.045
# 6710            6.7               0.3         0.34             7.5      0.036
# 6711            6.6               0.3         0.24             3.3      0.034
# 6712            8.0               0.2         0.31             5.6      0.049
# 6713            6.4               0.3         0.20            15.6      0.040
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                      43                   126   0.9909  3.01       0.63
# 1                       9                    31   0.9966  3.39       0.64
# 2                      21                   127   0.9976  3.23       0.63
# 3                      30                   131   0.9942  3.32       0.44
# 4                      35                   157   0.9998  3.17       0.50
# ...                   ...                   ...      ...   ...        ...
# 6709                   53                   176   0.9958  3.17       0.38
# 6710                   39                   124   0.9912  2.99       0.32
# 6711                   29                    99   0.9903  3.10       0.40
# 6712                   24                    97   0.9930  3.10       0.42
# 6713                   20                   142   0.9962  3.10       0.54
#
#       alcohol  quality   type
# 0        11.4        6  white
# 1         9.6        5    red
# 2         9.2        5    red
# 3        10.9        6  white
# 4         9.1        5  white
# ...       ...      ...    ...
# 6709      9.5        5  white
# 6710     12.4        8  white
# 6711     12.3        7  white
# 6712     10.9        5  white
# 6713     10.6        5  white
#
# [6714 rows x 13 columns]

# %%
def create_new_feature(data):
    # combine fixed and volatile acidity to create total acidity
    # and mean acidity
    acidity_features = ['fixed acidity', 'volatile acidity']
    data['total_acidity'] = data[acidity_features].sum(axis=1)
    data['average_acidity'] = data[acidity_features].mean(axis=1)
    
    #combine salts into total minerals and average minerals
    salt_features = ['chlorides','sulphates']
    data['total_minerals'] = data[salt_features].sum(axis=1)
    data['average_minerals'] = data[salt_features].mean(axis=1)
    
    #the sulfur that is not free
    sulfur_features = ['total sulfur dioxide','free sulfur dioxide']
    data['non_free_sulfur_dioxide'] = data[sulfur_features[0]] - data[sulfur_features[1]]
    
    #percentage of free sulfur
    data['percentage_free_sulfur'] = data[sulfur_features[1]] / data[sulfur_features[0]]
    
    #determine from all free sulfur how much is as salt
    data['percentage_salt_sulfur'] = data['sulphates'] / data['free sulfur dioxide']
    return data

# %%
train_df = create_new_feature(train_df)
test_df = create_new_feature(test_df)

# %%
type_dict = {cat:i for (i, cat) in enumerate(train_df['type'].unique())}
train_df['type']=train_df['type'].map(type_dict)
test_df['type']=test_df['type'].map(type_dict)

# %%
type_dict
# Out:
# {'white': 0, 'red': 1}

# %%
target = 'quality'
features = [c for c in train_df.columns if c not in target]

# %%
train_df.duplicated().sum()/len(train_df)
# Out:
# 0.1636878165028299

# %%
test_df[features].duplicated().sum()/len(test_df[features])
# Out:
# 0.13658536585365855

# %% [markdown]
# Should we drop duplicates?

# %%
train_df = train_df.drop_duplicates().reset_index(drop=True)

# %%
# merge train and test
train_df['isTest'] = 0
test_df['isTest'] = 1
data = pd.concat([train_df,test_df],axis=0)
data.shape
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13256\713258214.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['isTest'] = 0
# (6435, 22)

# %%
# Normalization data
from sklearn.preprocessing import StandardScaler
normal = StandardScaler()
col_normal = [col for col in data.columns if col != 'quality' and col != 'isTest' and col != 'type']
data[col_normal] = normal.fit_transform(data[col_normal])
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.488985         -0.307637     0.280039       -0.852070  -0.588504
# 1       0.323198          0.849153    -0.383382       -0.696625   0.094075
# 2       0.840042          0.849153     0.213697       -0.474561   0.448005
# 3       0.175528          0.270758     0.081013       -0.008225  -0.335697
# 4      -0.636655         -0.886032    -0.449725        3.367154   0.624970
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.753716              0.234512 -1.264388 -1.352002   0.571834
# 1            -1.172312             -1.429334  0.644361  1.022693   0.634706
# 2            -0.492537              0.252026  0.979229  0.022821   0.571834
# 3             0.017294              0.322082 -0.159323  0.585249  -0.622747
# 4             0.300533              0.777451  1.715939 -0.352130  -0.245511
#
#    ...  type  total_acidity  average_acidity  total_minerals  \
# 0  ...     0      -0.510532        -0.510532        0.375857
# 1  ...     1       0.417115         0.417115        0.581358
# 2  ...     1       0.916618         0.916618        0.603574
# 3  ...     0       0.203043         0.203043       -0.623877
# 4  ...     0      -0.724605        -0.724605       -0.079577
#
#    average_minerals  non_free_sulfur_dioxide  percentage_free_sulfur  \
# 0          0.375857                 0.001848                0.436843
# 1          0.581358                -1.331855                0.026457
# 2          0.603574                 0.504720               -0.980178
# 3         -0.623877                 0.395400               -0.467443
# 4         -0.079577                 0.854544               -0.516400
#
#    percentage_salt_sulfur  isTest  id
# 0               -0.439836       0 NaN
# 1                1.002390       0 NaN
# 2               -0.047762       0 NaN
# 3               -0.439440       0 NaN
# 4               -0.449171       0 NaN
#
# [5 rows x 22 columns]

# %%
# split data
train_df = data[data['isTest'] == 0]
test_df = data[data['isTest'] == 1]
train_df.drop('isTest',axis=1,inplace=True)
test_df.drop(['isTest','quality'],axis=1,inplace=True)
train_df.shape,test_df.shape
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13256\2720427290.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df.drop('isTest',axis=1,inplace=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13256\2720427290.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df.drop(['isTest','quality'],axis=1,inplace=True)
# ((5615, 21), (820, 20))

# %%
# processing imbalanced data using smogn
from smogn import smoter
train = smoter(data=train_df, y='quality', k=5)

# %%
# train_df = train_df[train_df['density']<1.01]

# %%
train_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.488985         -0.307637     0.280039       -0.852070  -0.588504
# 1          0.323198          0.849153    -0.383382       -0.696625   0.094075
# 2          0.840042          0.849153     0.213697       -0.474561   0.448005
# 3          0.175528          0.270758     0.081013       -0.008225  -0.335697
# 4         -0.636655         -0.886032    -0.449725        3.367154   0.624970
# ...             ...               ...          ...             ...        ...
# 6708      -0.119811          0.849153    -1.909252       -0.541180   0.448005
# 6709      -0.045976         -0.886032    -0.847777        0.591349  -0.335697
# 6710      -0.415150         -0.307637     0.147355        0.546936  -0.563224
# 6712       0.544703         -0.886032    -0.051672        0.125013  -0.234574
# 6713      -0.636655         -0.307637    -0.781435        2.345658  -0.462101
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0                0.753716              0.234512 -1.264388 -1.352002
# 1               -1.172312             -1.429334  0.644361  1.022693
# 2               -0.492537              0.252026  0.979229  0.022821
# 3                0.017294              0.322082 -0.159323  0.585249
# 4                0.300533              0.777451  1.715939 -0.352130
# ...                   ...                   ...       ...       ...
# 6708            -0.492537             -0.360970  0.945742  1.710104
# 6709             1.320195              1.110220  0.376466 -0.352130
# 6710             0.527124              0.199483 -1.163928 -1.476986
# 6712            -0.322594             -0.273399 -0.561165 -0.789574
# 6713            -0.549185              0.514738  0.510414 -0.789574
#
#       sulphates  ...  quality  type  total_acidity  average_acidity  \
# 0      0.571834  ...      6.0     0      -0.510532        -0.510532
# 1      0.634706  ...      5.0     1       0.417115         0.417115
# 2      0.571834  ...      5.0     1       0.916618         0.916618
# 3     -0.622747  ...      6.0     0       0.203043         0.203043
# 4     -0.245511  ...      5.0     0      -0.724605        -0.724605
# ...         ...  ...      ...   ...            ...              ...
# 6708   0.383216  ...      5.0     1      -0.011030        -0.011030
# 6709  -0.999984  ...      5.0     0      -0.153745        -0.153745
# 6710  -1.377220  ...      8.0     0      -0.439175        -0.439175
# 6712  -0.748493  ...      5.0     0       0.417115         0.417115
# 6713   0.005980  ...      5.0     0      -0.653247        -0.653247
#
#       total_minerals  average_minerals  non_free_sulfur_dioxide  \
# 0           0.375857          0.375857                 0.001848
# 1           0.581358          0.581358                -1.331855
# 2           0.603574          0.603574                 0.504720
# 3          -0.623877         -0.623877                 0.395400
# 4          -0.079577         -0.079577                 0.854544
# ...              ...               ...                      ...
# 6708        0.436952          0.436952                -0.260519
# 6709       -0.957122         -0.957122                 0.876408
# 6710       -1.340354         -1.340354                 0.045576
# 6712       -0.712743         -0.712743                -0.216792
# 6713       -0.096240         -0.096240                 0.854544
#
#       percentage_free_sulfur  percentage_salt_sulfur  id
# 0                   0.436843               -0.439836 NaN
# 1                   0.026457                1.002390 NaN
# 2                  -0.980178               -0.047762 NaN
# 3                  -0.467443               -0.439440 NaN
# 4                  -0.516400               -0.449171 NaN
# ...                      ...                     ...  ..
# 6708               -0.473458               -0.084254 NaN
# 6709                0.113563               -0.630942 NaN
# 6710                0.221339               -0.604495 NaN
# 6712               -0.319107               -0.367065 NaN
# 6713               -1.177603               -0.124395 NaN
#
# [5615 rows x 21 columns]

# %%
# sns.boxplot(train_df['density'])

# %%
# train_df[train_df['type']==0]

# %%
train_df_red = train_df[train_df['type']==type_dict['red']]
train_df_white = train_df[train_df['type']==type_dict['white']]
test_df_red = test_df[test_df['type']==type_dict['red']]
test_df_white = test_df[test_df['type']==type_dict['white']]

# %%
test_df_red.id
# Out:
# 0     -1.036521
# 5      1.187546
# 7      1.034199
# 12    -1.589210
# 13     1.703496
#          ...
# 804    1.291375
# 809   -0.637179
# 811   -0.180865
# 814    1.204052
# 817    1.004381
# Name: id, Length: 233, dtype: float64

# %%
# train = h2o.H2OFrame(train_df)
# test = h2o.H2OFrame(test_df)

# %%
def stratify(df, seed=42):
    stratify = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
    df['fold'] = np.zeros(len(df), dtype='int')
    
    for (i, (train_idx, val_idx)) in enumerate(stratify.split(df, y=df['quality'])):
        df['fold'].iloc[val_idx] = i
        
    return df

# %%
train_df_red = stratify(train_df_red, seed=30)
train_df_red
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13256\1914683325.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fold'] = np.zeros(len(df), dtype='int')
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13256\1914683325.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fold'].iloc[val_idx] = i
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1          0.323198          0.849153    -0.383382       -0.696625   0.094075
# 2          0.840042          0.849153     0.213697       -0.474561   0.448005
# 18         1.135381          0.270758     1.142487       -0.496767   0.624970
# 20        -0.193646          0.270758    -0.847777       -0.607799   0.321601
# 21         0.692372          0.270758     0.412723       -0.541180   0.877777
# ...             ...               ...          ...             ...        ...
# 6690       0.618537         -0.307637     0.280039       -0.630006  -0.259855
# 6695      -0.710490         -0.307637     1.076145       -0.718831   0.271040
# 6703      -0.193646          0.849153    -1.511199       -0.674419   0.574408
# 6704      -1.448838          2.005943    -0.847777       -0.785451   2.596865
# 6708      -0.119811          0.849153    -1.909252       -0.541180   0.448005
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 1               -1.172312             -1.429334  0.644361  1.022693
# 2               -0.492537              0.252026  0.979229  0.022821
# 18              -0.662481             -0.028201  1.180150  0.460265
# 20              -0.662481             -1.341763  0.041598  1.022693
# 21              -0.379241             -0.921423  1.079690  0.522757
# ...                   ...                   ...       ...       ...
# 6690             0.300533             -1.044022  0.108572  0.272789
# 6695            -0.662481             -0.903909  0.409953  1.335153
# 6703            -1.115664             -1.692046  0.041598  1.272661
# 6704            -1.285607             -0.886395 -0.226296  2.460008
# 6708            -0.492537             -0.360970  0.945742  1.710104
#
#       sulphates  ...  type  total_acidity  average_acidity  total_minerals  \
# 1      0.634706  ...     1       0.417115         0.417115        0.581358
# 2      0.571834  ...     1       0.916618         0.916618        0.603574
# 18     0.383216  ...     1       1.130690         1.130690        0.475831
# 20     0.131725  ...     1      -0.153745        -0.153745        0.187018
# 21     1.074815  ...     1       0.702545         0.702545        1.142320
# ...         ...  ...   ...            ...              ...             ...
# 6690   2.960996  ...     1       0.559830         0.559830        2.558611
# 6695   1.514924  ...     1      -0.724605        -0.724605        1.397808
# 6703   0.320343  ...     1      -0.082387        -0.082387        0.409182
# 6704   0.446088  ...     1      -1.152749        -1.152749        0.964590
# 6708   0.383216  ...     1      -0.011030        -0.011030        0.436952
#
#       average_minerals  non_free_sulfur_dioxide  percentage_free_sulfur  \
# 1             0.581358                -1.331855                0.026457
# 2             0.603574                 0.504720               -0.980178
# 18            0.475831                 0.220488               -1.005891
# 20            0.187018                -1.419311                1.715434
# 21            1.142320                -1.003895                0.775670
# ...                ...                      ...                     ...
# 6690          2.558611                -1.419311                3.007294
# 6695          1.397808                -0.872711                0.064794
# 6703          0.409182                -1.681678                2.722325
# 6704          0.964590                -0.610343               -1.402678
# 6708          0.436952                -0.260519               -0.473458
#
#       percentage_salt_sulfur  id  fold
# 1                   1.002390 NaN     1
# 2                  -0.047762 NaN     0
# 18                  0.037385 NaN     4
# 20                 -0.019380 NaN     4
# 21                 -0.025550 NaN     0
# ...                      ...  ..   ...
# 6690               -0.076955 NaN     2
# 6695                0.292828 NaN     2
# 6703                0.693021 NaN     0
# 6704                1.411909 NaN     3
# 6708               -0.084254 NaN     2
#
# [1563 rows x 22 columns]

# %%
train_df_white = stratify(train_df_white, seed=29)
train_df_white
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13256\1914683325.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fold'] = np.zeros(len(df), dtype='int')
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13256\1914683325.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fold'].iloc[val_idx] = i
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.488985         -0.307637     0.280039       -0.852070  -0.588504
# 3          0.175528          0.270758     0.081013       -0.008225  -0.335697
# 4         -0.636655         -0.886032    -0.449725        3.367154   0.624970
# 5          0.249363         -0.307637     1.341514        1.812703  -0.411539
# 6         -0.636655         -0.307637     0.545408        0.258252  -0.462101
# ...             ...               ...          ...             ...        ...
# 6707      -0.267481          0.270758     2.004935        1.524019  -0.335697
# 6709      -0.045976         -0.886032    -0.847777        0.591349  -0.335697
# 6710      -0.415150         -0.307637     0.147355        0.546936  -0.563224
# 6712       0.544703         -0.886032    -0.051672        0.125013  -0.234574
# 6713      -0.636655         -0.307637    -0.781435        2.345658  -0.462101
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0                0.753716              0.234512 -1.264388 -1.352002
# 3                0.017294              0.322082 -0.159323  0.585249
# 4                0.300533              0.777451  1.715939 -0.352130
# 5                1.773378              0.619823  1.247124 -1.539478
# 6                0.923660              0.987621  0.209032 -0.477114
# ...                   ...                   ...       ...       ...
# 6707             1.320195              0.759936  0.945742 -0.664590
# 6709             1.320195              1.110220  0.376466 -0.352130
# 6710             0.527124              0.199483 -1.163928 -1.476986
# 6712            -0.322594             -0.273399 -0.561165 -0.789574
# 6713            -0.549185              0.514738  0.510414 -0.789574
#
#       sulphates  ...  type  total_acidity  average_acidity  total_minerals  \
# 0      0.571834  ...     0      -0.510532        -0.510532        0.375857
# 3     -0.622747  ...     0       0.203043         0.203043       -0.623877
# 4     -0.245511  ...     0      -0.724605        -0.724605       -0.079577
# 5     -0.434129  ...     0       0.203043         0.203043       -0.473917
# 6     -0.497002  ...     0      -0.653247        -0.653247       -0.540566
# ...         ...  ...   ...            ...              ...             ...
# 6707  -0.559875  ...     0      -0.225102        -0.225102       -0.568336
# 6709  -0.999984  ...     0      -0.153745        -0.153745       -0.957122
# 6710  -1.377220  ...     0      -0.439175        -0.439175       -1.340354
# 6712  -0.748493  ...     0       0.417115         0.417115       -0.712743
# 6713   0.005980  ...     0      -0.653247        -0.653247       -0.096240
#
#       average_minerals  non_free_sulfur_dioxide  percentage_free_sulfur  \
# 0             0.375857                 0.001848                0.436843
# 3            -0.623877                 0.395400               -0.467443
# 4            -0.079577                 0.854544               -0.516400
# 5            -0.473917                 0.089304                1.007889
# 6            -0.540566                 0.876408               -0.119609
# ...                ...                      ...                     ...
# 6707         -0.568336                 0.439128                0.424549
# 6709         -0.957122                 0.876408                0.113563
# 6710         -1.340354                 0.045576                0.221339
# 6712         -0.712743                -0.216792               -0.319107
# 6713         -0.096240                 0.854544               -1.177603
#
#       percentage_salt_sulfur  id  fold
# 0                  -0.439836 NaN     4
# 3                  -0.439440 NaN     4
# 4                  -0.449171 NaN     4
# 5                  -0.617273 NaN     2
# 6                  -0.558647 NaN     2
# ...                      ...  ..   ...
# 6707               -0.597204 NaN     1
# 6709               -0.630942 NaN     4
# 6710               -0.604495 NaN     4
# 6712               -0.367065 NaN     2
# 6713               -0.124395 NaN     1
#
# [4052 rows x 22 columns]

# %%
train_white = h2o.H2OFrame(train_df_white)
train_red = h2o.H2OFrame(train_df_red)

test_white = h2o.H2OFrame(test_df_white)
test_red = h2o.H2OFrame(test_df_red)
# Out:
# ---------------------------------------------------------------------------
# H2OConnectionError                        Traceback (most recent call last)
# d:\AI1606\Ky_5\AIL302m\Kaggle\code\automl-split-by-type.ipynb Cell 30 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/AI1606/Ky_5/AIL302m/Kaggle/code/automl-split-by-type.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> train_white = h2o.H2OFrame(train_df_white)
#       <a href='vscode-notebook-cell:/d%3A/AI1606/Ky_5/AIL302m/Kaggle/code/automl-split-by-type.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> train_red = h2o.H2OFrame(train_df_red)
#       <a href='vscode-notebook-cell:/d%3A/AI1606/Ky_5/AIL302m/Kaggle/code/automl-split-by-type.ipynb#X32sZmlsZQ%3D%3D?line=3'>4</a> test_white = h2o.H2OFrame(test_df_white)
#
# File d:\Python_Environment\lib\site-packages\h2o\frame.py:113, in H2OFrame.__init__(self, python_obj, destination_frame, header, separator, column_names, column_types, na_strings, skipped_columns)
#     111 self._is_frame = True  # Indicate that this is an actual frame, allowing typechecks to be made
#     112 if python_obj is not None:
# --> 113     self._upload_python_object(python_obj, destination_frame, header, separator,
#     114                                column_names, column_types, na_strings, skipped_columns)
#
# File d:\Python_Environment\lib\site-packages\h2o\frame.py:154, in H2OFrame._upload_python_object(self, python_obj, destination_frame, header, separator, column_names, column_types, na_strings, skipped_columns)
#     152     csv_writer.writerows(data_to_write)
#     153 tmp_file.close()  # close the streams
# --> 154 self._upload_parse(tmp_path, destination_frame, 1, separator, column_names, column_types, na_strings, skipped_columns)
#     155 os.remove(tmp_path)
#
# File d:\Python_Environment\lib\site-packages\h2o\frame.py:456, in H2OFrame._upload_parse(self, path, destination_frame, header, sep, column_names, column_types, na_strings, skipped_columns, quotechar, escapechar)
#     454 def _upload_parse(self, path, destination_frame, header, sep, column_names, column_types, na_strings, skipped_columns=None,
#     455                   quotechar=None, escapechar=None):
# --> 456     ret = h2o.api("POST /3/PostFile", filename=path)
#     457     rawkey = ret["destination_frame"]
#     458     self._parse(rawkey, destination_frame, header, sep, column_names, column_types, na_strings, skipped_columns,
#     459                 quotechar=quotechar, escapechar=escapechar)
#
# File d:\Python_Environment\lib\site-packages\h2o\h2o.py:123, in api(endpoint, data, json, filename, save_to)
#     103 """
#     104 Perform a REST API request to a previously connected server.
#     105
#    (...)
#     120 >>> res["table"].show()
#     121 """
#     122 # type checks are performed in H2OConnection class
# --> 123 _check_connection()
#     124 return h2oconn.request(endpoint, data=data, json=json, filename=filename, save_to=save_to)
#
# File d:\Python_Environment\lib\site-packages\h2o\h2o.py:2494, in _check_connection()
#    2492 def _check_connection():
#    2493     if not cluster():
# -> 2494         raise H2OConnectionError("Not connected to a cluster. Did you run `h2o.init()` or `h2o.connect()`?")
#
# H2OConnectionError: Not connected to a cluster. Did you run `h2o.init()` or `h2o.connect()`?

# %%
len(test_red)
# Out:
# 233

# %%
target = 'quality'
features = [c for c in train_df.columns if c not in [target, 'type', 'fold']]
features
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol']

# %%
# type_dict = {cat:i for (i, cat) in enumerate(train['type'].unique().as_data_frame())}
# # type_dict
# # {'white': 0, 'red': 1}
# train['type']=train['type'].map(type_dict)
# test['type']=test['type'].map(type_dict)

# train['type'] = train['type'].asfactor()
# test['type'] = test['type'].asfactor()

# %%
# Run AutoML for 20 base models
aml = H2OAutoML(
    max_models=20, 
                seed=1, 
#                 max_runtime_secs = 60*60
               )
aml.train(x=features, y=target, training_frame=train_white,     fold_column='fold')
# Out:
# AutoML progress: |
# 02:58:43.118: Fold column fold will be used for cross-validation. nfolds parameter will be ignored.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# Model Details
# =============
# H2OStackedEnsembleEstimator :  Stacked Ensemble
# Model Key:  StackedEnsemble_AllModels_1_AutoML_2_20220614_25843
#
# No model summary for this model
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.06302859647409952
# RMSE: 0.25105496703729946
# MAE: 0.19068940572564008
# RMSLE: 0.03765740627978781
# R^2: 0.9223828627185502
# Mean Residual Deviance: 0.06302859647409952
# Null degrees of freedom: 4051
# Residual degrees of freedom: 4045
# Null deviance: 3290.4057255677694
# Residual deviance: 255.39187291305123
# AIC: 314.6742292782539
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 0.43822090447423756
# RMSE: 0.661982556019596
# MAE: 0.5066079744365157
# RMSLE: 0.09870809284592329
# R^2: 0.46034888915612726
# Mean Residual Deviance: 0.43822090447423756
# Null degrees of freedom: 4051
# Residual degrees of freedom: 4044
# Null deviance: 3290.413677499588
# Residual deviance: 1775.6711049296107
# AIC: 8174.047610886789
#
# Cross-Validation Metrics Summary:
#                                  mean        sd  cv_1_valid  cv_2_valid  \
# 0                     mae    0.506664  0.007139    0.498832    0.501848
# 1  mean_residual_deviance    0.438212  0.011033    0.452261    0.426507
# 2                     mse    0.438212  0.011033    0.452261    0.426507
# 3           null_deviance  658.082760  4.311973  660.835500  661.987240
# 4                      r2    0.460364  0.012725    0.444967    0.477477
# 5       residual_deviance  355.127870  8.971119  366.783330  345.897220
# 6                    rmse    0.661934  0.008325    0.672503    0.653075
# 7                   rmsle    0.098700  0.001338    0.100322    0.097189
#
#    cv_3_valid  cv_4_valid  cv_5_valid
# 0    0.515388    0.504411    0.512841
# 1    0.436470    0.429270    0.446554
# 2    0.436470    0.429270    0.446554
# 3  653.387900  653.387900  660.815200
# 4    0.458911    0.467837    0.452628
# 5  353.540800  347.709000  361.708920
# 6    0.660659    0.655187    0.668247
# 7    0.098854    0.097522    0.099615

# %%
# View the AutoML Leaderboard
lb = aml.leaderboard
lb.head(rows=lb.nrows)  # Print all rows instead of default (10 rows)
# Out:
# <table>
# <thead>
# <tr><th>model_id                                              </th><th style="text-align: right;">    rmse</th><th style="text-align: right;">     mse</th><th style="text-align: right;">     mae</th><th style="text-align: right;">    rmsle</th><th style="text-align: right;">  mean_residual_deviance</th></tr>
# </thead>
# <tbody>
# <tr><td>StackedEnsemble_AllModels_1_AutoML_2_20220614_25843   </td><td style="text-align: right;">0.661983</td><td style="text-align: right;">0.438221</td><td style="text-align: right;">0.506608</td><td style="text-align: right;">0.0987081</td><td style="text-align: right;">                0.438221</td></tr>
# <tr><td>StackedEnsemble_BestOfFamily_1_AutoML_2_20220614_25843</td><td style="text-align: right;">0.663791</td><td style="text-align: right;">0.440618</td><td style="text-align: right;">0.508002</td><td style="text-align: right;">0.0989468</td><td style="text-align: right;">                0.440618</td></tr>
# <tr><td>DRF_1_AutoML_2_20220614_25843                         </td><td style="text-align: right;">0.671783</td><td style="text-align: right;">0.451293</td><td style="text-align: right;">0.515737</td><td style="text-align: right;">0.100347 </td><td style="text-align: right;">                0.451293</td></tr>
# <tr><td>XRT_1_AutoML_2_20220614_25843                         </td><td style="text-align: right;">0.674161</td><td style="text-align: right;">0.454493</td><td style="text-align: right;">0.520131</td><td style="text-align: right;">0.100607 </td><td style="text-align: right;">                0.454493</td></tr>
# <tr><td>GBM_4_AutoML_2_20220614_25843                         </td><td style="text-align: right;">0.69488 </td><td style="text-align: right;">0.482859</td><td style="text-align: right;">0.536771</td><td style="text-align: right;">0.10323  </td><td style="text-align: right;">                0.482859</td></tr>
# <tr><td>XGBoost_grid_1_AutoML_2_20220614_25843_model_2        </td><td style="text-align: right;">0.699323</td><td style="text-align: right;">0.489052</td><td style="text-align: right;">0.536927</td><td style="text-align: right;">0.104254 </td><td style="text-align: right;">                0.489052</td></tr>
# <tr><td>GBM_5_AutoML_2_20220614_25843                         </td><td style="text-align: right;">0.700658</td><td style="text-align: right;">0.490922</td><td style="text-align: right;">0.544808</td><td style="text-align: right;">0.103951 </td><td style="text-align: right;">                0.490922</td></tr>
# <tr><td>GBM_3_AutoML_2_20220614_25843                         </td><td style="text-align: right;">0.702317</td><td style="text-align: right;">0.49325 </td><td style="text-align: right;">0.544696</td><td style="text-align: right;">0.104259 </td><td style="text-align: right;">                0.49325 </td></tr>
# <tr><td>GBM_2_AutoML_2_20220614_25843                         </td><td style="text-align: right;">0.702567</td><td style="text-align: right;">0.4936  </td><td style="text-align: right;">0.546465</td><td style="text-align: right;">0.104122 </td><td style="text-align: right;">                0.4936  </td></tr>
# <tr><td>GBM_grid_1_AutoML_2_20220614_25843_model_1            </td><td style="text-align: right;">0.706437</td><td style="text-align: right;">0.499054</td><td style="text-align: right;">0.547563</td><td style="text-align: right;">0.104927 </td><td style="text-align: right;">                0.499054</td></tr>
# <tr><td>DeepLearning_grid_3_AutoML_2_20220614_25843_model_1   </td><td style="text-align: right;">0.71571 </td><td style="text-align: right;">0.51224 </td><td style="text-align: right;">0.545959</td><td style="text-align: right;">0.105511 </td><td style="text-align: right;">                0.51224 </td></tr>
# <tr><td>GBM_1_AutoML_2_20220614_25843                         </td><td style="text-align: right;">0.718393</td><td style="text-align: right;">0.516088</td><td style="text-align: right;">0.556517</td><td style="text-align: right;">0.106236 </td><td style="text-align: right;">                0.516088</td></tr>
# <tr><td>XGBoost_2_AutoML_2_20220614_25843                     </td><td style="text-align: right;">0.720075</td><td style="text-align: right;">0.518507</td><td style="text-align: right;">0.55485 </td><td style="text-align: right;">0.10722  </td><td style="text-align: right;">                0.518507</td></tr>
# <tr><td>XGBoost_grid_1_AutoML_2_20220614_25843_model_3        </td><td style="text-align: right;">0.721428</td><td style="text-align: right;">0.520459</td><td style="text-align: right;">0.555943</td><td style="text-align: right;">0.107234 </td><td style="text-align: right;">                0.520459</td></tr>
# <tr><td>GBM_grid_1_AutoML_2_20220614_25843_model_2            </td><td style="text-align: right;">0.721779</td><td style="text-align: right;">0.520966</td><td style="text-align: right;">0.562014</td><td style="text-align: right;">0.106619 </td><td style="text-align: right;">                0.520966</td></tr>
# <tr><td>DeepLearning_grid_2_AutoML_2_20220614_25843_model_1   </td><td style="text-align: right;">0.721915</td><td style="text-align: right;">0.521161</td><td style="text-align: right;">0.552427</td><td style="text-align: right;">0.106456 </td><td style="text-align: right;">                0.521161</td></tr>
# <tr><td>XGBoost_3_AutoML_2_20220614_25843                     </td><td style="text-align: right;">0.722053</td><td style="text-align: right;">0.52136 </td><td style="text-align: right;">0.557036</td><td style="text-align: right;">0.107107 </td><td style="text-align: right;">                0.52136 </td></tr>
# <tr><td>DeepLearning_grid_1_AutoML_2_20220614_25843_model_1   </td><td style="text-align: right;">0.723213</td><td style="text-align: right;">0.523038</td><td style="text-align: right;">0.557915</td><td style="text-align: right;">0.106724 </td><td style="text-align: right;">                0.523038</td></tr>
# <tr><td>XGBoost_grid_1_AutoML_2_20220614_25843_model_1        </td><td style="text-align: right;">0.73076 </td><td style="text-align: right;">0.53401 </td><td style="text-align: right;">0.559085</td><td style="text-align: right;">0.108752 </td><td style="text-align: right;">                0.53401 </td></tr>
# <tr><td>XGBoost_1_AutoML_2_20220614_25843                     </td><td style="text-align: right;">0.736663</td><td style="text-align: right;">0.542673</td><td style="text-align: right;">0.570991</td><td style="text-align: right;">0.10975  </td><td style="text-align: right;">                0.542673</td></tr>
# <tr><td>DeepLearning_1_AutoML_2_20220614_25843                </td><td style="text-align: right;">0.74433 </td><td style="text-align: right;">0.554027</td><td style="text-align: right;">0.577535</td><td style="text-align: right;">0.109876 </td><td style="text-align: right;">                0.554027</td></tr>
# <tr><td>GLM_1_AutoML_2_20220614_25843                         </td><td style="text-align: right;">0.761612</td><td style="text-align: right;">0.580053</td><td style="text-align: right;">0.587907</td><td style="text-align: right;">0.112501 </td><td style="text-align: right;">                0.580053</td></tr>
# </tbody>
# </table>

# %%
# mean_squared_error(aml.predict(train_white).as_data_frame(), train_white[target].as_data_frame(), squared=False)

# %%
# type(aml.predict(train_white))

# %%
# pred = aml.predict(test)
# pred.head()

# %%
# submission_df = pd.DataFrame({'id':test.as_data_frame()['id'], 'quality':pred.as_data_frame()['predict']})

# submission_df

# %%
# submission_df.to_csv('submission.csv', index=False)

# %%
# aml.leader.base_models

# %%
aml.leader.metalearner()
# Out:
# Model Details
# =============
# H2OGeneralizedLinearEstimator :  Generalized Linear Modeling
# Model Key:  metalearner_AUTO_StackedEnsemble_AllModels_1_AutoML_2_20220614_25843
#
#
# GLM Model: summary
#        family      link                                 regularization  \
# 0    gaussian  identity  Elastic Net (alpha = 0.5, lambda = 0.006094 )
#
#                                                            lambda_search  \
# 0  nlambda = 100, lambda.max = 0.769, lambda.min = 0.006094, lambda.1...
#
#    number_of_predictors_total number_of_active_predictors  \
# 0                          20                           6
#
#    number_of_iterations  \
# 0                    53
#
#                                                           training_frame
# 0  levelone_training_StackedEnsemble_AllModels_1_AutoML_2_20220614_25843
# ModelMetricsRegressionGLM: glm
# ** Reported on train data. **
#
# MSE: 0.43604564810319363
# RMSE: 0.660337525893534
# MAE: 0.5049370934764137
# RMSLE: 0.09847742809132419
# R^2: 0.46302762836053024
# Mean Residual Deviance: 0.43604564810319363
# Null degrees of freedom: 4051
# Residual degrees of freedom: 4045
# Null deviance: 3290.4057255677694
# Residual deviance: 1766.8569661141405
# AIC: 8151.884064705501
#
# ModelMetricsRegressionGLM: glm
# ** Reported on cross-validation data. **
#
# MSE: 0.43822090447423756
# RMSE: 0.661982556019596
# MAE: 0.5066079744365157
# RMSLE: 0.09870809284592329
# R^2: 0.46034888915612726
# Mean Residual Deviance: 0.43822090447423756
# Null degrees of freedom: 4051
# Residual degrees of freedom: 4044
# Null deviance: 3290.413677499588
# Residual deviance: 1775.6711049296107
# AIC: 8174.047610886789
#
# Cross-Validation Metrics Summary:
#                                  mean        sd  cv_1_valid  cv_2_valid  \
# 0                     mae    0.506664  0.007139    0.498832    0.501848
# 1  mean_residual_deviance    0.438212  0.011033    0.452261    0.426507
# 2                     mse    0.438212  0.011033    0.452261    0.426507
# 3           null_deviance  658.082760  4.311973  660.835500  661.987240
# 4                      r2    0.460364  0.012725    0.444967    0.477477
# 5       residual_deviance  355.127870  8.971119  366.783330  345.897220
# 6                    rmse    0.661934  0.008325    0.672503    0.653075
# 7                   rmsle    0.098700  0.001338    0.100322    0.097189
#
#    cv_3_valid  cv_4_valid  cv_5_valid
# 0    0.515388    0.504411    0.512841
# 1    0.436470    0.429270    0.446554
# 2    0.436470    0.429270    0.446554
# 3  653.387900  653.387900  660.815200
# 4    0.458911    0.467837    0.452628
# 5  353.540800  347.709000  361.708920
# 6    0.660659    0.655187    0.668247
# 7    0.098854    0.097522    0.099615
# Scoring History:
#                 timestamp    duration  iteration lambda  predictors  \
# 0     2022-06-14 03:12:46   0.000 sec          1  .77E0           1
# 1     2022-06-14 03:12:46   0.001 sec          2   .7E0           4
# 2     2022-06-14 03:12:46   0.005 sec          3  .64E0           5
# 3     2022-06-14 03:12:46   0.018 sec          4  .58E0           5
# 4     2022-06-14 03:12:46   0.021 sec          5  .53E0           5
# 5     2022-06-14 03:12:46   0.027 sec          6  .48E0           5
# 6     2022-06-14 03:12:46   0.029 sec          7  .44E0           7
# 7     2022-06-14 03:12:46   0.030 sec          8   .4E0           8
# 8     2022-06-14 03:12:46   0.032 sec          9  .37E0           8
# 9     2022-06-14 03:12:46   0.033 sec         10  .33E0           8
# 10    2022-06-14 03:12:46   0.039 sec         11   .3E0           8
# 11    2022-06-14 03:12:46   0.041 sec         12  .28E0           8
# 12    2022-06-14 03:12:46   0.042 sec         13  .25E0           8
# 13    2022-06-14 03:12:46   0.044 sec         14  .23E0           9
# 14    2022-06-14 03:12:46   0.046 sec         15  .21E0          10
# 15    2022-06-14 03:12:46   0.052 sec         16  .19E0          10
# 16    2022-06-14 03:12:46   0.054 sec         17  .17E0          10
# 17    2022-06-14 03:12:46   0.055 sec         18  .16E0          11
# 18    2022-06-14 03:12:46   0.058 sec         19  .14E0          10
# 19    2022-06-14 03:12:46   0.060 sec         20  .13E0           9
#
#     deviance_train  alpha  iterations training_rmse training_deviance  \
# 0         0.812045    0.5         NaN
# 1         0.767216    0.5         NaN
# 2         0.725177    0.5         NaN
# 3         0.686577    0.5         NaN
# 4         0.652890    0.5         5.0      0.808016           0.65289
# 5         0.623215    0.5         NaN
# 6         0.595352    0.5         NaN
# 7         0.571953    0.5         NaN
# 8         0.551662    0.5         NaN
# 9         0.534561    0.5        10.0      0.731137          0.534561
# 10        0.520045    0.5         NaN
# 11        0.507719    0.5         NaN
# 12        0.497262    0.5         NaN
# 13        0.488361    0.5         NaN
# 14        0.480503    0.5        15.0      0.693183          0.480503
# 15        0.473728    0.5         NaN
# 16        0.468066    0.5         NaN
# 17        0.463250    0.5         NaN
# 18        0.459349    0.5         NaN
# 19        0.455522    0.5        20.0      0.674924          0.455522
#
#    training_mae training_r2
# 0
# 1
# 2
# 3
# 4      0.616408    0.195993
# 5
# 6
# 7
# 8
# 9       0.56778     0.34171
# 10
# 11
# 12
# 13
# 14     0.540731     0.40828
# 15
# 16
# 17
# 18
# 19     0.524239    0.439044
# See the whole table with table.as_data_frame()
#
# Variable Importances:
#                                                variable  relative_importance  \
# 0                         DRF_1_AutoML_2_20220614_25843             0.191980
# 1                         XRT_1_AutoML_2_20220614_25843             0.133280
# 2                     XGBoost_2_AutoML_2_20220614_25843             0.103393
# 3        XGBoost_grid_1_AutoML_2_20220614_25843_model_2             0.096037
# 4   DeepLearning_grid_3_AutoML_2_20220614_25843_model_1             0.071658
# 5                     XGBoost_1_AutoML_2_20220614_25843             0.043611
# 6                         GBM_4_AutoML_2_20220614_25843             0.000000
# 7                         GBM_5_AutoML_2_20220614_25843             0.000000
# 8                         GBM_3_AutoML_2_20220614_25843             0.000000
# 9                         GBM_2_AutoML_2_20220614_25843             0.000000
# 10           GBM_grid_1_AutoML_2_20220614_25843_model_1             0.000000
# 11                        GBM_1_AutoML_2_20220614_25843             0.000000
# 12       XGBoost_grid_1_AutoML_2_20220614_25843_model_3             0.000000
# 13           GBM_grid_1_AutoML_2_20220614_25843_model_2             0.000000
# 14  DeepLearning_grid_2_AutoML_2_20220614_25843_model_1             0.000000
# 15                    XGBoost_3_AutoML_2_20220614_25843             0.000000
# 16  DeepLearning_grid_1_AutoML_2_20220614_25843_model_1             0.000000
# 17       XGBoost_grid_1_AutoML_2_20220614_25843_model_1             0.000000
# 18               DeepLearning_1_AutoML_2_20220614_25843             0.000000
# 19                        GLM_1_AutoML_2_20220614_25843             0.000000
#
#     scaled_importance  percentage
# 0            1.000000    0.299988
# 1            0.694238    0.208263
# 2            0.538564    0.161563
# 3            0.500244    0.150067
# 4            0.373256    0.111972
# 5            0.227164    0.068146
# 6            0.000000    0.000000
# 7            0.000000    0.000000
# 8            0.000000    0.000000
# 9            0.000000    0.000000
# 10           0.000000    0.000000
# 11           0.000000    0.000000
# 12           0.000000    0.000000
# 13           0.000000    0.000000
# 14           0.000000    0.000000
# 15           0.000000    0.000000
# 16           0.000000    0.000000
# 17           0.000000    0.000000
# 18           0.000000    0.000000
# 19           0.000000    0.000000

# %%
# h2o.get_model('XRT_1_AutoML_3_20220609_25602')

# %%
# h2o.get_model('XGBoost_grid_1_AutoML_3_20220609_25602_model_2')

# %%
# Run AutoML for 20 base models
aml_red = H2OAutoML(
    max_models=20, 
                seed=5, 
#                 max_runtime_secs = 60*60
               )
aml_red.train(x=features, y=target, training_frame=train_red, fold_column='fold')
# Out:
# AutoML progress: |
# 03:13:23.194: Fold column fold will be used for cross-validation. nfolds parameter will be ignored.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# Model Details
# =============
# H2OStackedEnsembleEstimator :  Stacked Ensemble
# Model Key:  StackedEnsemble_BestOfFamily_1_AutoML_3_20220614_31323
#
# No model summary for this model
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.06986048775837325
# RMSE: 0.2643113462535675
# MAE: 0.1981077576945904
# RMSLE: 0.04145903240750547
# R^2: 0.9000835982955395
# Mean Residual Deviance: 0.06986048775837325
# Null degrees of freedom: 1562
# Residual degrees of freedom: 1557
# Null deviance: 1092.833013435689
# Residual deviance: 109.19194236633739
# AIC: 290.0601996327403
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 0.3820225353967769
# RMSE: 0.6180797160535014
# MAE: 0.46675943400852704
# RMSLE: 0.09570796219271935
# R^2: 0.4536208043825767
# Mean Residual Deviance: 0.3820225353967769
# Null degrees of freedom: 1562
# Residual degrees of freedom: 1557
# Null deviance: 1092.867654226258
# Residual deviance: 597.1012228251623
# AIC: 2945.5649686297297
#
# Cross-Validation Metrics Summary:
#                                  mean        sd  cv_1_valid  cv_2_valid  \
# 0                     mae    0.468004  0.012151    0.460161    0.469800
# 1  mean_residual_deviance    0.382550  0.013809    0.380028    0.388215
# 2                     mse    0.382550  0.013809    0.380028    0.388215
# 3           null_deviance  218.573530  3.229615  216.174130  222.174130
# 4                      r2    0.452687  0.022915    0.449750    0.453076
# 5       residual_deviance  119.582436  4.221552  118.948845  121.511420
# 6                    rmse    0.618426  0.011140    0.616464    0.623069
# 7                   rmsle    0.095735  0.002037    0.094811    0.097540
#
#    cv_3_valid  cv_4_valid  cv_5_valid
# 0    0.455771    0.487369    0.466917
# 1    0.365409    0.402443    0.376655
# 2    0.365409    0.402443    0.376655
# 3  222.018680  216.660780  215.839920
# 4    0.484821    0.420267    0.455522
# 5  114.373120  125.562280  117.516495
# 6    0.604491    0.634384    0.613723
# 7    0.094416    0.098261    0.093645

# %%
# View the AutoML Leaderboard
lb_red = aml_red.leaderboard
lb_red.head(rows=lb_red.nrows)  # Print all rows instead of default (10 rows)
# Out:
# <table>
# <thead>
# <tr><th>model_id                                              </th><th style="text-align: right;">    rmse</th><th style="text-align: right;">     mse</th><th style="text-align: right;">     mae</th><th style="text-align: right;">    rmsle</th><th style="text-align: right;">  mean_residual_deviance</th></tr>
# </thead>
# <tbody>
# <tr><td>StackedEnsemble_BestOfFamily_1_AutoML_3_20220614_31323</td><td style="text-align: right;">0.61808 </td><td style="text-align: right;">0.382023</td><td style="text-align: right;">0.466759</td><td style="text-align: right;">0.095708 </td><td style="text-align: right;">                0.382023</td></tr>
# <tr><td>StackedEnsemble_AllModels_1_AutoML_3_20220614_31323   </td><td style="text-align: right;">0.619038</td><td style="text-align: right;">0.383208</td><td style="text-align: right;">0.466648</td><td style="text-align: right;">0.0958107</td><td style="text-align: right;">                0.383208</td></tr>
# <tr><td>XRT_1_AutoML_3_20220614_31323                         </td><td style="text-align: right;">0.625475</td><td style="text-align: right;">0.391219</td><td style="text-align: right;">0.476175</td><td style="text-align: right;">0.0969651</td><td style="text-align: right;">                0.391219</td></tr>
# <tr><td>DRF_1_AutoML_3_20220614_31323                         </td><td style="text-align: right;">0.628785</td><td style="text-align: right;">0.39537 </td><td style="text-align: right;">0.475492</td><td style="text-align: right;">0.0975401</td><td style="text-align: right;">                0.39537 </td></tr>
# <tr><td>GBM_grid_1_AutoML_3_20220614_31323_model_1            </td><td style="text-align: right;">0.642278</td><td style="text-align: right;">0.412521</td><td style="text-align: right;">0.487909</td><td style="text-align: right;">0.0993878</td><td style="text-align: right;">                0.412521</td></tr>
# <tr><td>XGBoost_grid_1_AutoML_3_20220614_31323_model_1        </td><td style="text-align: right;">0.643812</td><td style="text-align: right;">0.414494</td><td style="text-align: right;">0.486062</td><td style="text-align: right;">0.0996406</td><td style="text-align: right;">                0.414494</td></tr>
# <tr><td>GBM_5_AutoML_3_20220614_31323                         </td><td style="text-align: right;">0.644639</td><td style="text-align: right;">0.41556 </td><td style="text-align: right;">0.490895</td><td style="text-align: right;">0.0996822</td><td style="text-align: right;">                0.41556 </td></tr>
# <tr><td>GBM_3_AutoML_3_20220614_31323                         </td><td style="text-align: right;">0.646489</td><td style="text-align: right;">0.417948</td><td style="text-align: right;">0.4938  </td><td style="text-align: right;">0.100196 </td><td style="text-align: right;">                0.417948</td></tr>
# <tr><td>GBM_4_AutoML_3_20220614_31323                         </td><td style="text-align: right;">0.64707 </td><td style="text-align: right;">0.418699</td><td style="text-align: right;">0.494308</td><td style="text-align: right;">0.100116 </td><td style="text-align: right;">                0.418699</td></tr>
# <tr><td>GBM_2_AutoML_3_20220614_31323                         </td><td style="text-align: right;">0.651403</td><td style="text-align: right;">0.424326</td><td style="text-align: right;">0.49869 </td><td style="text-align: right;">0.100809 </td><td style="text-align: right;">                0.424326</td></tr>
# <tr><td>DeepLearning_grid_1_AutoML_3_20220614_31323_model_1   </td><td style="text-align: right;">0.66759 </td><td style="text-align: right;">0.445677</td><td style="text-align: right;">0.520776</td><td style="text-align: right;">0.102606 </td><td style="text-align: right;">                0.445677</td></tr>
# <tr><td>DeepLearning_grid_3_AutoML_3_20220614_31323_model_1   </td><td style="text-align: right;">0.671726</td><td style="text-align: right;">0.451216</td><td style="text-align: right;">0.535927</td><td style="text-align: right;">0.104133 </td><td style="text-align: right;">                0.451216</td></tr>
# <tr><td>XGBoost_3_AutoML_3_20220614_31323                     </td><td style="text-align: right;">0.672199</td><td style="text-align: right;">0.451851</td><td style="text-align: right;">0.514484</td><td style="text-align: right;">0.103897 </td><td style="text-align: right;">                0.451851</td></tr>
# <tr><td>DeepLearning_grid_2_AutoML_3_20220614_31323_model_1   </td><td style="text-align: right;">0.672916</td><td style="text-align: right;">0.452815</td><td style="text-align: right;">0.533206</td><td style="text-align: right;">0.104518 </td><td style="text-align: right;">                0.452815</td></tr>
# <tr><td>GBM_1_AutoML_3_20220614_31323                         </td><td style="text-align: right;">0.677612</td><td style="text-align: right;">0.459158</td><td style="text-align: right;">0.520877</td><td style="text-align: right;">0.104649 </td><td style="text-align: right;">                0.459158</td></tr>
# <tr><td>XGBoost_2_AutoML_3_20220614_31323                     </td><td style="text-align: right;">0.678109</td><td style="text-align: right;">0.459832</td><td style="text-align: right;">0.514644</td><td style="text-align: right;">0.104662 </td><td style="text-align: right;">                0.459832</td></tr>
# <tr><td>GBM_grid_1_AutoML_3_20220614_31323_model_2            </td><td style="text-align: right;">0.682151</td><td style="text-align: right;">0.465329</td><td style="text-align: right;">0.523601</td><td style="text-align: right;">0.105306 </td><td style="text-align: right;">                0.465329</td></tr>
# <tr><td>XGBoost_1_AutoML_3_20220614_31323                     </td><td style="text-align: right;">0.682375</td><td style="text-align: right;">0.465636</td><td style="text-align: right;">0.525936</td><td style="text-align: right;">0.10529  </td><td style="text-align: right;">                0.465636</td></tr>
# <tr><td>XGBoost_grid_1_AutoML_3_20220614_31323_model_3        </td><td style="text-align: right;">0.684774</td><td style="text-align: right;">0.468916</td><td style="text-align: right;">0.512801</td><td style="text-align: right;">0.105787 </td><td style="text-align: right;">                0.468916</td></tr>
# <tr><td>XGBoost_grid_1_AutoML_3_20220614_31323_model_2        </td><td style="text-align: right;">0.692812</td><td style="text-align: right;">0.479988</td><td style="text-align: right;">0.532816</td><td style="text-align: right;">0.107078 </td><td style="text-align: right;">                0.479988</td></tr>
# <tr><td>GLM_1_AutoML_3_20220614_31323                         </td><td style="text-align: right;">0.704165</td><td style="text-align: right;">0.495848</td><td style="text-align: right;">0.549342</td><td style="text-align: right;">0.108376 </td><td style="text-align: right;">                0.495848</td></tr>
# <tr><td>DeepLearning_1_AutoML_3_20220614_31323                </td><td style="text-align: right;">0.704978</td><td style="text-align: right;">0.496994</td><td style="text-align: right;">0.542819</td><td style="text-align: right;">0.10886  </td><td style="text-align: right;">                0.496994</td></tr>
# </tbody>
# </table>

# %%
aml_red.leader.metalearner()
# Out:
# Model Details
# =============
# H2OGeneralizedLinearEstimator :  Generalized Linear Modeling
# Model Key:  metalearner_AUTO_StackedEnsemble_BestOfFamily_1_AutoML_3_20220614_31323
#
#
# GLM Model: summary
#        family      link                                 regularization  \
# 0    gaussian  identity  Elastic Net (alpha = 0.5, lambda = 0.004975 )
#
#                                                            lambda_search  \
# 0  nlambda = 100, lambda.max = 0.6278, lambda.min = 0.004975, lambda....
#
#    number_of_predictors_total number_of_active_predictors  \
# 0                           6                           5
#
#    number_of_iterations  \
# 0                    53
#
#                                                           training_frame
# 0  levelone_training_StackedEnsemble_BestOfFamily_1_AutoML_3_20220614...
# ModelMetricsRegressionGLM: glm
# ** Reported on train data. **
#
# MSE: 0.3800391406615523
# RMSE: 0.6164731467481388
# MAE: 0.4651134064847684
# RMSLE: 0.09544645119514805
# R^2: 0.4564575103871016
# Mean Residual Deviance: 0.3800391406615523
# Null degrees of freedom: 1562
# Residual degrees of freedom: 1557
# Null deviance: 1092.833013435689
# Residual deviance: 594.0011768540063
# AIC: 2937.429005181186
#
# ModelMetricsRegressionGLM: glm
# ** Reported on cross-validation data. **
#
# MSE: 0.3820225353967769
# RMSE: 0.6180797160535014
# MAE: 0.46675943400852704
# RMSLE: 0.09570796219271935
# R^2: 0.4536208043825767
# Mean Residual Deviance: 0.3820225353967769
# Null degrees of freedom: 1562
# Residual degrees of freedom: 1557
# Null deviance: 1092.867654226258
# Residual deviance: 597.1012228251623
# AIC: 2945.5649686297297
#
# Cross-Validation Metrics Summary:
#                                  mean        sd  cv_1_valid  cv_2_valid  \
# 0                     mae    0.468004  0.012151    0.460161    0.469800
# 1  mean_residual_deviance    0.382550  0.013809    0.380028    0.388215
# 2                     mse    0.382550  0.013809    0.380028    0.388215
# 3           null_deviance  218.573530  3.229615  216.174130  222.174130
# 4                      r2    0.452687  0.022915    0.449750    0.453076
# 5       residual_deviance  119.582436  4.221552  118.948845  121.511420
# 6                    rmse    0.618426  0.011140    0.616464    0.623069
# 7                   rmsle    0.095735  0.002037    0.094811    0.097540
#
#    cv_3_valid  cv_4_valid  cv_5_valid
# 0    0.455771    0.487369    0.466917
# 1    0.365409    0.402443    0.376655
# 2    0.365409    0.402443    0.376655
# 3  222.018680  216.660780  215.839920
# 4    0.484821    0.420267    0.455522
# 5  114.373120  125.562280  117.516495
# 6    0.604491    0.634384    0.613723
# 7    0.094416    0.098261    0.093645
# Scoring History:
#                 timestamp    duration  iteration lambda  predictors  \
# 0     2022-06-14 03:18:15   0.000 sec          1  .63E0           1
# 1     2022-06-14 03:18:15   0.001 sec          2  .57E0           2
# 2     2022-06-14 03:18:15   0.001 sec          3  .52E0           5
# 3     2022-06-14 03:18:15   0.002 sec          4  .47E0           5
# 4     2022-06-14 03:18:15   0.003 sec          5  .43E0           5
# 5     2022-06-14 03:18:15   0.005 sec          6  .39E0           5
# 6     2022-06-14 03:18:15   0.006 sec          7  .36E0           5
# 7     2022-06-14 03:18:15   0.006 sec          8  .33E0           5
# 8     2022-06-14 03:18:15   0.007 sec          9   .3E0           6
# 9     2022-06-14 03:18:15   0.007 sec         10  .27E0           6
# 10    2022-06-14 03:18:15   0.010 sec         11  .25E0           6
# 11    2022-06-14 03:18:15   0.010 sec         12  .23E0           6
# 12    2022-06-14 03:18:15   0.011 sec         13  .21E0           6
# 13    2022-06-14 03:18:15   0.011 sec         14  .19E0           6
# 14    2022-06-14 03:18:15   0.012 sec         15  .17E0           6
# 15    2022-06-14 03:18:15   0.015 sec         16  .16E0           6
# 16    2022-06-14 03:18:15   0.015 sec         17  .14E0           6
# 17    2022-06-14 03:18:15   0.016 sec         18  .13E0           6
# 18    2022-06-14 03:18:15   0.016 sec         19  .12E0           6
# 19    2022-06-14 03:18:15   0.016 sec         20  .11E0           6
#
#     deviance_train  alpha  iterations training_rmse training_deviance  \
# 0         0.699189    0.5         NaN
# 1         0.672465    0.5         NaN
# 2         0.635874    0.5         NaN
# 3         0.599842    0.5         NaN
# 4         0.568605    0.5         5.0      0.754059          0.568605
# 5         0.541475    0.5         NaN
# 6         0.518034    0.5         NaN
# 7         0.497819    0.5         NaN
# 8         0.480388    0.5         NaN
# 9         0.464699    0.5        10.0      0.681688          0.464699
# 10        0.451662    0.5         NaN
# 11        0.440525    0.5         NaN
# 12        0.431080    0.5         NaN
# 13        0.423075    0.5         NaN
# 14        0.416301    0.5        15.0      0.645214          0.416301
# 15        0.410574    0.5         NaN
# 16        0.405739    0.5         NaN
# 17        0.401660    0.5         NaN
# 18        0.398222    0.5         NaN
# 19        0.395327    0.5        20.0       0.62875          0.395327
#
#    training_mae training_r2
# 0
# 1
# 2
# 3
# 4      0.633652    0.186765
# 5
# 6
# 7
# 8
# 9      0.551561    0.335375
# 10
# 11
# 12
# 13
# 14     0.506394    0.404595
# 15
# 16
# 17
# 18
# 19     0.484549    0.434593
# See the whole table with table.as_data_frame()
#
# Variable Importances:
#                                               variable  relative_importance  \
# 0                        XRT_1_AutoML_3_20220614_31323             0.181427
# 1                        DRF_1_AutoML_3_20220614_31323             0.120882
# 2           GBM_grid_1_AutoML_3_20220614_31323_model_1             0.103474
# 3       XGBoost_grid_1_AutoML_3_20220614_31323_model_1             0.090013
# 4  DeepLearning_grid_1_AutoML_3_20220614_31323_model_1             0.087654
# 5                        GLM_1_AutoML_3_20220614_31323             0.000000
#
#    scaled_importance  percentage
# 0           1.000000    0.310956
# 1           0.666281    0.207184
# 2           0.570334    0.177349
# 3           0.496138    0.154277
# 4           0.483134    0.150233
# 5           0.000000    0.000000

# %%
test_y_red = aml_red.predict(test_red[features]).as_data_frame()['predict']
test_y_red
# Out:
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# 0      6.896752
# 1      5.217917
# 2      6.431069
# 3      5.811726
# 4      5.503815
#          ...
# 228    6.632493
# 229    6.657870
# 230    6.204942
# 231    5.550302
# 232    6.039355
# Name: predict, Length: 233, dtype: float64

# %%
test_y_white = aml.predict(test_white[features]).as_data_frame()['predict']
test_y_white
# Out:
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# 0      5.588221
# 1      4.896008
# 2      6.127342
# 3      5.742914
# 4      5.236204
#          ...
# 582    5.825178
# 583    6.487025
# 584    5.607108
# 585    6.579523
# 586    5.965495
# Name: predict, Length: 587, dtype: float64

# %%
test_df_red
# Out:
#        id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0    1257            7.2              0.25         0.37             2.5
# 5    5434           10.2              0.54         0.37            15.4
# 7    5146            6.2              0.39         0.43             2.0
# 12    219            6.0              0.31         0.47             3.6
# 13   6403           10.4              0.41         0.55             3.2
# ..    ...            ...               ...          ...             ...
# 804  5629            7.2              0.39         0.44             2.6
# 809  2007            8.5              0.32         0.42             2.3
# 811  2864           10.6              0.36         0.57             2.3
# 814  5465            9.1              0.52         0.33             1.3
# 817  5090            8.3              0.26         0.37             1.4
#
#      chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0        0.063                 11.0                  41.0  0.99439  3.52
# 5        0.214                 55.0                  95.0  1.00369  3.18
# 7        0.071                 14.0                  24.0  0.99428  3.45
# 12       0.067                 18.0                  42.0  0.99549  3.39
# 13       0.076                 22.0                  54.0  0.99960  3.15
# ..         ...                  ...                   ...      ...   ...
# 804      0.066                 22.0                  48.0  0.99494  3.30
# 809      0.075                 12.0                  19.0  0.99434  3.14
# 811      0.087                  6.0                  20.0  0.99676  3.14
# 814      0.070                  9.0                  30.0  0.99780  3.24
# 817      0.076                  8.0                  23.0  0.99740  3.26
#
#      sulphates  alcohol  type
# 0         0.80     12.4     1
# 5         0.77      9.0     1
# 7         0.87     11.2     1
# 12        0.66     11.0     1
# 13        0.89      9.9     1
# ..         ...      ...   ...
# 804       0.84     11.5     1
# 809       0.71     11.8     1
# 811       0.72     11.1     1
# 814       0.60      9.3     1
# 817       0.70      9.6     1
#
# [233 rows x 13 columns]

# %%
submission_df_red = pd.DataFrame({'id':test_df_red['id'].reset_index(drop=True), 'quality':test_y_red})

submission_df_red
# Out:
#        id   quality
# 0    1257  6.896752
# 1    5434  5.217917
# 2    5146  6.431069
# 3     219  5.811726
# 4    6403  5.503815
# ..    ...       ...
# 228  5629  6.632493
# 229  2007  6.657870
# 230  2864  6.204942
# 231  5465  5.550302
# 232  5090  6.039355
#
# [233 rows x 2 columns]

# %%
submission_df_white = pd.DataFrame({'id':test_df_white.id.reset_index(drop=True), 'quality':test_y_white})

submission_df_white
# Out:
#        id   quality
# 0    6409  5.588221
# 1     136  4.896008
# 2    1631  6.127342
# 3    6084  5.742914
# 4    1094  5.236204
# ..    ...       ...
# 582  1366  5.825178
# 583  4646  6.487025
# 584   734  5.607108
# 585  1579  6.579523
# 586  5688  5.965495
#
# [587 rows x 2 columns]

# %%
submission_df = pd.concat([submission_df_red, submission_df_white])

# %%
submission_df.to_csv('submission.csv', index=False)

# %%
submission_df
# Out:
#        id   quality
# 0    1257  6.896752
# 1    5434  5.217917
# 2    5146  6.431069
# 3     219  5.811726
# 4    6403  5.503815
# ..    ...       ...
# 582  1366  5.825178
# 583  4646  6.487025
# 584   734  5.607108
# 585  1579  6.579523
# 586  5688  5.965495
#
# [820 rows x 2 columns]
